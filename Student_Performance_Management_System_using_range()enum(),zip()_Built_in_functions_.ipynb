# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeswari-sri/Pythoncourse_Fundamentals/blob/main/Student_Performance_Management_System_using_range()enum()%2Czip()_Built_in_functions_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study – Student Performance Management System**
#
# **Instructions**
#
# Create two lists:
# students
# marks
#
# Use range() to:
# Access and print student names and marks using index positions
#
# Use enumerate() to:
# Display student index number and student name
#
# Use zip() to:
# Combine student names and marks together
#
# Display all outputs using for loops
#
# Use proper headings with print() statements
#
# Print the final result in a clean format

# %%
students =["Yoga","Haashraa","Sri","kadar"]
Marks=[99,100,87,94]

print("----- Using range() -----")
for i in range(len(students)):
  print(f"{students[i]} : {Marks [i]}")

print("----- Using enumerate() -----")
for index,name in enumerate(students):
  print(index, "-" ,name)

print("----- Using zip() -----")
for stud,mar in zip(students,Marks):
  print(f"{stud} - {mar}")

print("----------- Using Both Zip() and Enumerate()--------------")
for i ,(stud,mar) in enumerate(zip(students,Marks)):
  print(f"{stud} {i} : Marks {mar}")
# Out:
# ----- Using range() -----
# Yoga : 99
# Haashraa : 100
# Sri : 87
# kadar : 94
# ----- Using enumerate() -----
# 0 - Yoga
# 1 - Haashraa
# 2 - Sri
# 3 - kadar
# ----- Using zip() -----
# Yoga - 99
# Haashraa - 100
# Sri - 87
# kadar - 94
# ----------- Using Both Zip() and Enumerate()--------------
# Yoga 0 : Marks 99
# Haashraa 1 : Marks 100
# Sri 2 : Marks 87
# kadar 3 : Marks 94
