# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeswari-sri/Pythoncourse_Fundamentals/blob/main/Student_ID_Card_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Student ID Card Generator**

# %%
#Create variables: student_name, roll_number, department
 #Take input from the user using input() function
 #Convert student_name and department into uppercase using upper()

student_name=input("Enter student name:").upper()
roll_number=input("Enter roll number:")
department=input("Enter department").upper()

# Extract first 4 letters of student_name and department using slicing
first_4_name = student_name[:4]
first_4_dept = department[:4]

 #Create Student ID by combining name, department, and roll number

StudID=student_name + "_" + department + "_" + roll_number


#Display Name, Department, Roll Number, and Student ID only
# Use print() and f-string for output display

print('\n ---------STUDENT DETAILS ---------')
print(f'Name:{student_name}')
print(f'Department:{department}')
print(f'Roll_Number:{roll_number}')
print(f'Student_ID :{StudID}')
# Out:
# Enter student name:Yoga
# Enter roll number:1561
# Enter departmentInformation technology
#
#  ---------STUDENT DETAILS ---------
# Name:YOGA
# Department:INFORMATION TECHNOLOGY
# Roll_Number:1561
# Student_ID :YOGA_INFORMATION TECHNOLOGY_1561
