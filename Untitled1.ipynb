# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeswari-sri/Pythoncourse_Fundamentals/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study Scholarship Eligibility Checker
# Instructions:
#
# Create variables: student_name, marks, attendance, family_income.
#
# Use conditional statements (if, elif, else) to:
#
# Award Full Scholarship if marks ≥ 90 and attendance ≥ 90.
# Award Half Scholarship if marks ≥ 80 or attendance ≥ 85.
# Award Need-Based Scholarship if marks ≥ 70 and family_income < 30000.
# Otherwise, display Not Eligible.
# Display all data (no loops).

# %%
student_name=input("Enter your name : ")
Marks=int(input("Enter your score : "))
Attendance=int(input("Enter Your Attedence  : "))
Family_income=int(input("Enter Your Income : "))

if Marks >= 90 and Attendance >=90:
  Scholarship= "Full Scholarship"
elif Marks >=80 and Attendance >=85:
    scholarship = "Half Scholarship"
elif Marks >= 70 and Family_income <= 30000:
    scholarship = "Need-Based Scholarship"
else:
    Scholarship = "Not Eligible"


print("Student:", student_name)
print("Marks:", Marks)
print("Attendance:", Attendance)
print("Family Income:", Family_income)
print("Scholarship Status:", Scholarship)
# Out:
# Enter your name : Yoga
# Enter your score : 90
# Enter Your Attedence  : 90
# Enter Your Income : 45000
# Student: Yoga
# Marks: 90
# Attendance: 90
# Family Income: 45000
# Scholarship Status: Full Scholarship
