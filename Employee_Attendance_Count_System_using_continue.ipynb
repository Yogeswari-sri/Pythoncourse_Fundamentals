# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeswari-sri/Pythoncourse_Fundamentals/blob/main/Employee_Attendance_Count_System_using_continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Case Study – Employee Attendance Count System using continue**
#
# **Instructions:**
#
# 1. Create a list named `attendance` with values:
#    Present, Absent, Present, Leave, Present
#
# 2. Create count variables:
#
#    • present
#    • absent
#    • leave
#
# 3. Use a for loop to iterate through the attendance list.
#
# 4. Use continue statement to:
#    • Skip remaining conditions after counting Present employees
#
# 5. Count:
#    • Total Present employees
#    • Total Absent employees
#    • Total Leave employees
#
# 6. Display all counts using print()

# %%
attendance = ["Present", "Absent", "Leave"]

Absent = Present = Leave =0

for status in attendance:

     # Count Present Employee using Continue
    if status == "Present":
        Present += 1
        continue

    # Count absent employees
    if status == "Absent":
        Absent += 1

    # Count leave employees
    elif status == "Leave":
        Leave += 1

# Display counts
print("Total Present:", Present)
print("Total Absent:", Absent)
print("Total Leave :", Leave)
# Out:
# Total Present: 1
# Total Absent: 1
# Total Leave : 1
