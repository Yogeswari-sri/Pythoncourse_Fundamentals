# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogeswari-sri/Pythoncourse_Fundamentals/blob/main/Employee_Salary_Increment_using_List_Comprehension.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study – Employee Salary Increment using List Comprehension**

# %% [markdown]
# **Instructions**
#
# Create a list called salary
#
# Store employee salaries inside the list
#
# Use list comprehension to:
# Increase each salary by 10%
#
# Create another list to:
# Display only salaries greater than 50000
#
# Print:
#
# Original salary list
#
# Updated salary list
#
# Filtered salary list

# %%
salary=[26000,56000,78000]

updated_salary =[i* 1.10 for i in salary]

high_salary = [i for i in updated_salary if i > 50000]

print("Salary",salary)
print("After increasing 10 %",updated_salary)
print("Greater than 50000 salary list :",high_salary)
# Out:
# Salary [26000, 56000, 78000]
# After increasing 10 % [28600.000000000004, 61600.00000000001, 85800.0]
# Greater than 50000 salary list : [61600.00000000001, 85800.0]
